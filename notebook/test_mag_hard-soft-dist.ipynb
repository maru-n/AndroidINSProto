# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import mpld3

# %%
data = np.load("../data/20150924_154153.npz")
data.keys()
# Out:
# ['pos', 'acl', 'qtn', 'vel', 'time', 'mag', 'ang']

# %%
plt.plot(data['mag'][:,0], data['mag'][:,1])
plt.grid()
lim = abs(data['mag'][:,0:2]).max() * 1.05
plt.xlim(-lim, lim)
plt.ylim(-lim, lim)
plt.show()

# %%
data_uncomp = np.load("../data/20150924_155651.npz")

# %%
plt.plot(data_uncomp['mag'][:,0], data_uncomp['mag'][:,1])
plt.grid()
lim = abs(data_uncomp['mag'][:,0:2]).max() * 1.05
plt.xlim(-lim, lim)
plt.ylim(-lim, lim)
plt.show()
